# %% [raw]
# ---
# title: "Random Investment Strategy Analysis"
# subtitle: "Hypothesis Testing and Performance Evaluation"
# author: "Your Name"
# date: today
# bibliography: references.bib
# format:
#   pdf:
#     reference-location: margin
#     citation-location: margin
#     documentclass: scrreprt
#     classoption:
#       - DIV=11
#       - headings=small
#       - parskip=half
#     include-in-header: buildfiles/preamble.tex
#     highlight-style: buildfiles/berg.theme
#     code-line-numbers: true
#     fontsize: 11pt
#     toc: true
#     echo: true
#     keep-tex: true
# jupyter: python3
# execute:
#   enabled: true
#   freeze: false
# engine: jupyter
# ---

# %% [markdown]
# # Random Investment Strategy: Hypothesis Analysis
#
# This report evaluates the **Random Investment Strategy** hypothesis - a contrarian approach testing whether portfolio selection through randomization can outperform traditional methods.
#
# **Research Question:** Can a purely random stock selection strategy generate competitive risk-adjusted returns compared to market benchmarks?
#
# [This template demonstrates Tufte-style margins, financial tables, and professional PDF output]{.aside}

# %% [markdown]
# ## Executive Summary
#
# The Random Investment Strategy challenges conventional portfolio theory by testing whether systematic randomization can produce competitive returns.
#
# ::: {.column-margin}
# **Hypothesis Testing:**
# - Random selection vs. benchmarks
# - Risk-adjusted performance
# - Statistical significance
# :::

# %% [markdown]
# ## Methodology
#
# We simulate the Random Investment Strategy by selecting stocks through controlled randomization and evaluating performance metrics against theoretical foundations [@markowitz1952portfolio].

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotext as plt_term
from finmodel import PlotextChart, FinancialTable

# %% [markdown]
# ### Strategy Assumptions
#
# The Random Investment Strategy uses the following assumptions for portfolio construction and evaluation.
#
# [Assumptions are displayed using Financial Modeling Standard format]{.aside}

# %%
# Strategy Assumptions - displayed as Financial Modeling Standard
assumptions_data = pd.DataFrame({
    'Value': [
        100_000,      # Initial capital
        3,            # Number of stocks
        100,          # Trading days
        0.02,         # Expected volatility Stock A
        0.015,        # Expected volatility Stock B
        0.025,        # Expected volatility Stock C
    ]
}, index=[
    'Initial Capital ($)',
    'Portfolio Size (N)',
    'Simulation Period (days)',
    'Stock A Volatility',
    'Stock B Volatility', 
    'Stock C Volatility',
])

# Display as Assumption table (grey background)
FinancialTable(assumptions_data, style='assumptions')
# Out:
# \begin{longtable}[]{|l|r|}
# \toprule
# \textbf{} & \textbf{Value} \\
# \midrule
# \endhead
# Initial Capital ($) & \cellcolor[HTML]{D9D9D9}100,000.00 \\
# Portfolio Size (N) & \cellcolor[HTML]{D9D9D9}3.00 \\
# Simulation Period (days) & \cellcolor[HTML]{D9D9D9}100.00 \\
# Stock A Volatility & \cellcolor[HTML]{D9D9D9}0.0200 \\
# Stock B Volatility & \cellcolor[HTML]{D9D9D9}0.0150 \\
# Stock C Volatility & \cellcolor[HTML]{D9D9D9}0.0250 \\
# \bottomrule
# \end{longtable}

# %% [markdown]
# ### Portfolio Simulation
#
# Generate random portfolio returns using Monte Carlo simulation with the defined volatility assumptions.
#
# [Monte Carlo methods are standard for portfolio risk analysis]{.aside}

# %%
#| column: page
#| label: portfolio-simulation

# Generate random portfolio returns - full width for better readability
np.random.seed(42)
dates = pd.date_range('2024-01-01', periods=100, freq='D')

# Extract volatilities from assumptions
vol_a = assumptions_data.loc['Stock A Volatility', 'Value']
vol_b = assumptions_data.loc['Stock B Volatility', 'Value']
vol_c = assumptions_data.loc['Stock C Volatility', 'Value']

# Simulate price paths
portfolio = pd.DataFrame({
    'Date': dates,
    'Stock_A': 100 * np.cumprod(1 + np.random.randn(100) * vol_a),
    'Stock_B': 100 * np.cumprod(1 + np.random.randn(100) * vol_b),
    'Stock_C': 100 * np.cumprod(1 + np.random.randn(100) * vol_c)
})

# Show first 5 rows as calculation table (blue background)
FinancialTable(portfolio.head().set_index('Date'), style='calculations')
# Out:
# \begin{longtable}[]{|l|r|r|r|}
# \toprule
# \rowcolor[HTML]{8FAADC}
# \textbf{Date} & \textbf{Stock\_A} & \textbf{Stock\_B} & \textbf{Stock\_C} \\
# \midrule
# \endhead
# \cellcolor[HTML]{D9E2F3}2024-01-01 00:00:00 & \cellcolor[HTML]{FFFFFF}100.99 & \cellcolor[HTML]{FFFFFF}97.88 & \cellcolor[HTML]{FFFFFF}100.89 \\
# \cellcolor[HTML]{D9E2F3}2024-01-02 00:00:00 & \cellcolor[HTML]{FFFFFF}100.71 & \cellcolor[HTML]{FFFFFF}97.26 & \cellcolor[HTML]{FFFFFF}102.31 \\
# \cellcolor[HTML]{D9E2F3}2024-01-03 00:00:00 & \cellcolor[HTML]{FFFFFF}102.02 & \cellcolor[HTML]{FFFFFF}96.76 & \cellcolor[HTML]{FFFFFF}105.08 \\
# \cellcolor[HTML]{D9E2F3}2024-01-04 00:00:00 & \cellcolor[HTML]{FFFFFF}105.13 & \cellcolor[HTML]{FFFFFF}95.59 & \cellcolor[HTML]{FFFFFF}107.85 \\
# \cellcolor[HTML]{D9E2F3}2024-01-05 00:00:00 & \cellcolor[HTML]{FFFFFF}104.63 & \cellcolor[HTML]{FFFFFF}95.36 & \cellcolor[HTML]{FFFFFF}104.13 \\
# \bottomrule
# \end{longtable}

# %% [markdown]
# ## Performance Analysis
#
# Calculate key performance metrics for the Random Investment Strategy.
#
# ::: {.column-margin}
# **Key Metrics:**
# - Annualized returns
# - Risk-adjusted ratios
# - Sharpe Ratio [@sharpe1966mutual]
# :::

# %%
# Calculate portfolio statistics - displayed as Results (yellow background)
returns = portfolio[['Stock_A', 'Stock_B', 'Stock_C']].pct_change().dropna()

statistics = pd.DataFrame({
    'Stock A': [
        returns['Stock_A'].mean() * 252,
        returns['Stock_A'].std() * np.sqrt(252),
        (returns['Stock_A'].mean() * 252) / (returns['Stock_A'].std() * np.sqrt(252)),
    ],
    'Stock B': [
        returns['Stock_B'].mean() * 252,
        returns['Stock_B'].std() * np.sqrt(252),
        (returns['Stock_B'].mean() * 252) / (returns['Stock_B'].std() * np.sqrt(252)),
    ],
    'Stock C': [
        returns['Stock_C'].mean() * 252,
        returns['Stock_C'].std() * np.sqrt(252),
        (returns['Stock_C'].mean() * 252) / (returns['Stock_C'].std() * np.sqrt(252)),
    ]
}, index=[
    'Mean Return (annualized)',
    'Volatility (annualized)',
    'Sharpe Ratio'
])

# Display as Results table (yellow background for outputs)
FinancialTable(statistics, style='results')
# Out:
# \begin{longtable}[]{|l|r|r|r|}
# \toprule
# \rowcolor[HTML]{FFC000}
# \textbf{} & \textbf{Stock A} & \textbf{Stock B} & \textbf{Stock C} \\
# \midrule
# \endhead
# \cellcolor[HTML]{FFF2CC}Mean Return (annualized) & \cellcolor[HTML]{FFF2CC}-0.5540 & \cellcolor[HTML]{FFF2CC}0.1392 & \cellcolor[HTML]{FFF2CC}0.3902 \\
# \cellcolor[HTML]{FFF2CC}Volatility (annualized) & \cellcolor[HTML]{FFF2CC}0.2892 & \cellcolor[HTML]{FFF2CC}0.2256 & \cellcolor[HTML]{FFF2CC}0.4323 \\
# \cellcolor[HTML]{FFF2CC}Sharpe Ratio & \cellcolor[HTML]{FFF2CC}-1.92 & \cellcolor[HTML]{FFF2CC}0.6171 & \cellcolor[HTML]{FFF2CC}0.9025 \\
# \bottomrule
# \end{longtable}

# %% [markdown]
# ## Visualization
#
# Visual analysis of the Random Investment Strategy performance over the simulation period.

# %%
#| label: fig-portfolio
#| fig-cap: "Random Investment Strategy - Simulated Performance"

plt.figure(figsize=(10, 6))
plt.plot(portfolio['Date'], portfolio['Stock_A'], label='Stock A', linewidth=2)
plt.plot(portfolio['Date'], portfolio['Stock_B'], label='Stock B', linewidth=2)
plt.plot(portfolio['Date'], portfolio['Stock_C'], label='Stock C', linewidth=2)
plt.axhline(y=100, color='gray', linestyle='--', alpha=0.5, label='Initial Value')
plt.xlabel('Date')
plt.ylabel('Portfolio Value (Index: 100)')
plt.title('Random Investment Strategy Performance')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
#| label: fig-returns-plotext
#| fig-cap: "Returns Distribution - Terminal Plot (plotext)"

# Terminal-based plotting with plotext
import plotext as plt
from finmodel import PlotextChart

# Calculate returns for Stock A
stock_a_returns = returns['Stock_A'].values

# Create histogram
plt.clear_figure()
plt.hist(stock_a_returns, bins=20)
plt.theme('pro')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.title('Stock A Returns Distribution (Random Strategy)')

# Render with PlotextChart wrapper
ansi_output = plt.build()
PlotextChart(ansi_output, size='medium')
# Out:
# \begin{Verbatim}[commandchars=\\\{\}]
# \normalsize
# \fontfamily{Berkeley Mono}\selectfont
#                    Stock A Returns Distribution (Random Strategy)
#     ┌──────────────────────────────────────────────────────────────────────────┐
# 14.0┤                                 \textcolor{blue!80}{████}                                     │
#     │                                 \textcolor{blue!80}{████}                                     │
#     │                                 \textcolor{blue!80}{████}                                     │
# 11.7┤                                 \textcolor{blue!80}{████████}                                 │
#     │                                 \textcolor{blue!80}{████████}                                 │
#  9.3┤                                 \textcolor{blue!80}{████████}   \textcolor{blue!80}{████████}                      │
# ...

# %% [markdown]
# ## Conclusion
#
# This analysis demonstrates the Random Investment Strategy evaluation framework with:
#
# 1. **Financial Modeling Standard tables** - Assumptions (grey), Calculations (blue), Outputs (yellow)
# 2. **Tufte-style layout** - Margin annotations for context
# 3. **Full-width code blocks** - When horizontal space is needed (`#| column: page`)
# 4. **Professional visualizations** - Both matplotlib and plotext terminal plots
# 5. **Citation management** - Academic references with BibTeX [@markowitz1952portfolio]
#
# ### Key Findings
#
# The Random Investment Strategy simulation shows:
# - Variable performance across randomly selected assets
# - Risk-adjusted returns (Sharpe ratios) indicate strategy effectiveness
# - Visual analysis reveals performance dispersion
#
# [See Docs/ for complete documentation on template features]{.aside}
#
# ## References
#
# ::: {#refs}
# :::
